# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshu7466/Python/blob/main/Deep_Learning/Dropout_Layer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/codebasics/py/master/DeepLearningML/13_dropout_layer/sonar_dataset.csv", header= None)
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
X = df.drop(60, axis=1)
y = df[60]

# %%
y = pd.get_dummies(df[60],drop_first=True)
y.sample(5)
# Out:
#      R
# 22   1
# 9    1
# 65   1
# 2    1
# 190  0

# %%
y.value_counts()
# Out:
# R
# 0    111
# 1     97
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=1)

# %%
X_train.shape
# Out:
# (156, 60)

# %%
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(60,input_dim=60,activation='relu'),
    keras.layers.Dense(30,activation='relu'),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dense(1,activation='sigmoid')
])

model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)
model.fit(X_train,y_train,epochs=100,batch_size=8)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 2ms/step - loss: 0.6830 - accuracy: 0.5385
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6501 - accuracy: 0.6731
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6257 - accuracy: 0.7500
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5896 - accuracy: 0.7949
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5505 - accuracy: 0.8077
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5151 - accuracy: 0.7821
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4701 - accuracy: 0.8205
# Epoch 8/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4457 - accuracy: 0.8013
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4129 - accuracy: 0.8333
# Epoch 10/100
# ...

# %%
model.evaluate(X_test,y_test)
# Out:
# 2/2 [==============================] - 0s 11ms/step - loss: 1.3813 - accuracy: 0.7308
# [1.381277322769165, 0.7307692170143127]

# %%
y_pred = model.predict(X_test).reshape(-1)
print(y_pred[:10])

y_pred = np.round(y_pred)
print(y_pred[:10])
# Out:
# 2/2 [==============================] - 0s 12ms/step
# [2.7797129e-09 9.5677352e-01 9.9975151e-01 2.0293774e-06 1.0000000e+00
#  9.9999774e-01 1.3074677e-01 1.0000000e+00 3.2103819e-06 1.0000000e+00]
# [0. 1. 1. 0. 1. 1. 0. 1. 0. 1.]

# %%
y_test[:10]
# Out:
#      R
# 186  0
# 155  0
# 165  0
# 200  0
# 58   1
# 34   1
# 151  0
# 18   1
# 202  0
# 62   1

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.89      0.77        27
#            1       0.82      0.56      0.67        25
#
#     accuracy                           0.73        52
#    macro avg       0.75      0.72      0.72        52
# weighted avg       0.75      0.73      0.72        52

# %%
modeld = keras.Sequential([
    keras.layers.Dense(60,input_dim=60,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(30,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(15,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1,activation='sigmoid')
])

modeld.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)
modeld.fit(X_train,y_train,epochs=100,batch_size=8)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 2ms/step - loss: 0.7147 - accuracy: 0.5000
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7028 - accuracy: 0.5192
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7107 - accuracy: 0.5000
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6992 - accuracy: 0.5385
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6965 - accuracy: 0.5128
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7036 - accuracy: 0.5064
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6877 - accuracy: 0.5385
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6751 - accuracy: 0.5705
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6863 - accuracy: 0.4872
# Epoch 10/100
# ...

# %%
modeld.evaluate(X_test,y_test)
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4811 - accuracy: 0.7500
# [0.48106876015663147, 0.75]

# %%
y_prediction = modeld.predict(X_test).reshape(-1)
print(y_prediction[:10])
y_prediction = np.round(y_prediction)
print(y_prediction[:10])
# Out:
# 2/2 [==============================] - 0s 10ms/step
# [1.2131796e-04 8.6825114e-01 9.6203989e-01 2.2149330e-02 9.9969280e-01
#  8.8718283e-01 5.6552184e-01 9.9955207e-01 2.0280046e-02 9.9979836e-01]
# [0. 1. 1. 0. 1. 1. 1. 1. 0. 1.]

# %%
y_test[:10]
# Out:
#      R
# 186  0
# 155  0
# 165  0
# 200  0
# 58   1
# 34   1
# 151  0
# 18   1
# 202  0
# 62   1

# %%
print(classification_report(y_test,y_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77        27
#            1       0.77      0.68      0.72        25
#
#     accuracy                           0.75        52
#    macro avg       0.75      0.75      0.75        52
# weighted avg       0.75      0.75      0.75        52
